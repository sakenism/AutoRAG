# %%
import pandas as pd

# %%
df = pd.read_parquet('qa_test.parquet')

# %%
df
# Out:
#                                       qid  \
# 0    dcd50dfd-b395-4924-bf1c-476f3ed0af66
# 1    56bc5e42-bbd4-4ccb-8a73-7f1de1d654d3
# 2    8a1b7a56-a386-4d13-9225-6b92d17b1c08
# 3    fc65e92e-5a6d-4298-9a74-a893f0091b7f
# 4    9f3fc5d7-372b-4581-9439-591d02a29e37
# ..                                    ...
# 195  32da7357-31e6-4bbc-a728-917a0bc02eec
# 196  4256a199-732a-4b1e-8e96-193c14ff7f23
# 197  c1e31b43-c481-41d3-b9cd-a7ef06efb522
# 198  0844d7f9-7283-4932-8dbf-dca13d991468
# 199  9e3da65e-8c6e-4a6e-986a-2bfff1eadd86
#
#                                                  query  \
# 0                               What is the Milky Way?
# 1    Which force is nothing more than the bending o...
# 2    Which star is as bright as 23 Suns, and is orb...
# 3         What are the three primary colours of light?
# 4    Which three South American countries does the ...
# ..                                                 ...
# 195  What is the name of the London Underground sta...
# ...

# %%
st = set()
for elem in df['retrieval_gt']:
    for id in elem:
        st.add(id)
        
print(len(st))
# Out:
# 2097

# %%
df_corpus = pd.read_parquet('corpus.parquet')

# %%
df_corpus
# Out:
#           doc_id                                           contents  \
# 0         tc_2_4  Alvin and the Chipmunks (2007) - IMDb\nIMDb\n1...
# 1         tc_2_6  The Chipmunks - Biography | Billboard\nThe Chi...
# 2         tc_2_9  Alvin and the Chipmunks: The Squeakquel – EW.c...
# 3        tc_2_16  Alvin Seville | Alvin and the Chipmunks Wiki |...
# 4        tc_2_21  A Christmas Story | Christmas Specials Wiki | ...
# ...          ...                                                ...
# 5943   qz_3969_9  How to Fix a Slice in Golf: Diagnosing and Cor...
# 5944  qz_3969_23  Groundbreaking research on the best way to fix...
# 5945  qz_3969_36  Golf Today's A to Z of Golf\nThree under par s...
# 5946   qz_3971_0  Ex-EastEnders star Michelle Ryan set for massi...
# 5947   qz_3971_1  From EastEnders to Hollywood: How have Albert ...
#
#                                                metadata
# 0     {'last_modified_datetime': 2024-02-04 17:15:47...
# ...

# %%
len(df_corpus['contents'][0])
# Out:
# 8260

# %%
df_corpus[df_corpus['doc_id'] == 'tc_3130_0']['contents'].iloc[0]
# Out:
# "Milky Way Galaxy: Facts About Our Galactic Home\nMilky Way Galaxy: Facts About Our Galactic Home\nBy Nola Taylor Redd, Space.com Contributor |\nFebruary 22, 2013 11:24am ET\nMORE\nThis heavenly view of the Milky Way was taken in the South Pacific paradise of Mangaia, the most southerly of the Cook Islands. This image was chosen as one of the winners of the National Maritime Museum's Astrophotographer of the Year 2011 Contest.\nCredit: Tunc Tezel\nThe Milky Way galaxy is most significant to humans because it is home sweet home. But when it comes down to it, our galaxy is a typical barred spiral, much like billions of other galaxies in the universe. Let's take a look at the Milky Way.\nLocation, location, location\nA glance up at the night sky reveals a broad swath of light. Described by the ancients as a river, as milk, and as a path, among other things, the band has been visible in the heavens since Earth first formed. In reality, this intriguing line of light is the center of our g
# ...
